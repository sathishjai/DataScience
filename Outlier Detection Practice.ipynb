# %%
import pandas as pd
from sklearn.datasets import fetch_openml

# Load the Ames housing dataset
ames_housing = fetch_openml(name="house_prices", as_frame=True)

# Display the shape of the data
print(print("After Cleaning", df.shape))

# Display the feature names
print(ames_housing.feature_names)
ames_housing
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# After Cleaning (1460, 80)
# None
# ...

# %%
df = pd.DataFrame(ames_housing.data)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0   None  None        None
# 1         Lvl    AllPub  ...           0        0   None  None        None
# 2         Lvl    AllPub  ...           0        0   None  None        None
# 3         Lvl    AllPub  ...           0        0   None  None        None
# 4         Lvl    AllPub  ...           0        0   None  None        None
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df["Price"]=ames_housing.target

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  None      Reg
# 1        2          20       RL         80.0     9600   Pave  None      Reg
# 2        3          60       RL         68.0    11250   Pave  None      IR1
# 3        4          70       RL         60.0     9550   Pave  None      IR1
# 4        5          60       RL         84.0    14260   Pave  None      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  None      Reg
# 1456  1457          20       RL         85.0    13175   Pave  None      Reg
# 1457  1458          70       RL         66.0     9042   Pave  None      Reg
# 1458  1459          20       RL         68.0     9717   Pave  None      Reg
# 1459  1460          20       RL         75.0     9937   Pave  None      Reg
#
# ...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
boston_c = ames_df
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(boston_c['LotArea'], boston_c['SalePrice' ])
plt.show()

# %%
from scipy import stats
import numpy as np
zscore = np.abs(stats.zscore(ames_df['LotArea']))
print(zscore)
# Out:
# 0       0.207142
# 1       0.091886
# 2       0.073480
# 3       0.096897
# 4       0.375148
#           ...
# 1455    0.260560
# 1456    0.266407
# 1457    0.147810
# 1458    0.080160
# 1459    0.058112
# Name: LotArea, Length: 1460, dtype: float64

# %%
threshold = 3
np.where(zscore > 3)
# Out:
# (array([  53,  249,  313,  335,  384,  451,  457,  661,  706,  769,  848,
#         1298, 1396], dtype=int64),)

# %%
zscore[53]
# Out:
# 3.98424384357879

# %%
# negative zscore :
threshold = 3
np.where(zscore < -3)
# Out:
# (array([], dtype=int64),)

# %%
boston_clean = ames_df[zscore < 3]

# Display the shape of the original and cleaned DataFrames
print("Original shape:", ames_df.shape)
print("Cleaned shape:", boston_clean.shape)
# Out:
# Original shape: (1460, 81)
# Cleaned shape: (1447, 81)

# %%
boston_clean.shape
# Out:
# (1447, 81)

# %% [markdown]
# # Using IQR

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  None      Reg
# 1        2          20       RL         80.0     9600   Pave  None      Reg
# 2        3          60       RL         68.0    11250   Pave  None      IR1
# 3        4          70       RL         60.0     9550   Pave  None      IR1
# 4        5          60       RL         84.0    14260   Pave  None      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  None      Reg
# 1456  1457          20       RL         85.0    13175   Pave  None      Reg
# 1457  1458          70       RL         66.0     9042   Pave  None      Reg
# 1458  1459          20       RL         68.0     9717   Pave  None      Reg
# 1459  1460          20       RL         75.0     9937   Pave  None      Reg
#
# ...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x=df["LotArea"])
# Out:
# <Axes: xlabel='LotArea'>

# %%
def remove_outliers_iqr(df, feature):
    Q1=df[feature].quantile(0.25)
    Q3=df[feature].quantile(0.75)
    IQR=Q3-Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df [(df [feature] >= lower_bound) & (df[feature] <= upper_bound)]

# %%
A = remove_outliers_iqr(df, 'LotArea')

# %%
print("Before Cleaning", df.shape)
print("After Cleaning", A.shape)
# Out:
# Before Cleaning (1460, 81)
# After Cleaning (1391, 81)
